# %%
import pandas as pd
import numpy as np
df = pd.read_excel("Resources/data-alcohol.xlsx")
df.head()
# Out:
#    IndicatorCode                                          Indicator ValueType  \
# 0  SA_0000001400  Alcohol, recorded per capita (15+) consumption...   numeric
# 1  SA_0000001400  Alcohol, recorded per capita (15+) consumption...   numeric
# 2  SA_0000001400  Alcohol, recorded per capita (15+) consumption...   numeric
# 3  SA_0000001400  Alcohol, recorded per capita (15+) consumption...   numeric
# 4  SA_0000001400  Alcohol, recorded per capita (15+) consumption...   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 AGO
# 2                AFR         Africa       Country                 AGO
# 3                AFR         Africa       Country                 AGO
# 4                AFR         Africa       Country                 AGO
#
# ...

# %%
df=df[["Location","Period","FactValueNumeric","Dim1"]]
df
# Out:
#       Location  Period  FactValueNumeric                       Dim1
# 0       Angola    2019              5.84                  All types
# 1       Angola    2019              3.78                       Beer
# 2       Angola    2019              0.72                       Wine
# 3       Angola    2019              1.27                    Spirits
# 4       Angola    2019              0.08  Other alcoholic beverages
# ...        ...     ...               ...                        ...
# 47789    Samoa    1962              0.05                    Spirits
# 47790    Samoa    1961              0.61                  All types
# 47791    Samoa    1961              0.28                       Beer
# 47792    Samoa    1961              0.00                       Wine
# 47793    Samoa    1961              0.33                    Spirits
#
# [47794 rows x 4 columns]

# %%
df.dtypes
# Out:
# Location             object
# Period                int64
# FactValueNumeric    float64
# Dim1                 object
# dtype: object

# %%
df = df.loc[df["Period"] > 2014, :]
df
# Out:
#       Location  Period  FactValueNumeric                       Dim1
# 0       Angola    2019              5.84                  All types
# 1       Angola    2019              3.78                       Beer
# 2       Angola    2019              0.72                       Wine
# 3       Angola    2019              1.27                    Spirits
# 4       Angola    2019              0.08  Other alcoholic beverages
# ...        ...     ...               ...                        ...
# 47538    Samoa    2015              2.10                  All types
# 47539    Samoa    2015              1.90                       Beer
# 47540    Samoa    2015              0.03                       Wine
# 47541    Samoa    2015              0.17                    Spirits
# 47542    Samoa    2015              0.00  Other alcoholic beverages
#
# [4700 rows x 4 columns]

# %%
df = df.loc[df["Dim1"] == "All types" , :]
df
# Out:
#       Location  Period  FactValueNumeric       Dim1
# 0       Angola    2019              5.84  All types
# 5       Angola    2018              6.15  All types
# 10      Angola    2017              6.16  All types
# 15      Angola    2016              6.09  All types
# 20      Angola    2015              6.53  All types
# ...        ...     ...               ...        ...
# 47518    Samoa    2019              2.18  All types
# 47523    Samoa    2018              2.18  All types
# 47528    Samoa    2017              2.06  All types
# 47533    Samoa    2016              2.29  All types
# 47538    Samoa    2015              2.10  All types
#
# [940 rows x 4 columns]

# %%
df=df[["Location","Period","FactValueNumeric"]]
df
# Out:
#       Location  Period  FactValueNumeric
# 0       Angola    2019              5.84
# 5       Angola    2018              6.15
# 10      Angola    2017              6.16
# 15      Angola    2016              6.09
# 20      Angola    2015              6.53
# ...        ...     ...               ...
# 47518    Samoa    2019              2.18
# 47523    Samoa    2018              2.18
# 47528    Samoa    2017              2.06
# 47533    Samoa    2016              2.29
# 47538    Samoa    2015              2.10
#
# [940 rows x 3 columns]

# %%
df = df.rename(columns={ "Location":"country", "Period":"year","FactValueNumeric":"liters"})
df
# Out:
#       country  year  liters
# 0      Angola  2019    5.84
# 5      Angola  2018    6.15
# 10     Angola  2017    6.16
# 15     Angola  2016    6.09
# 20     Angola  2015    6.53
# ...       ...   ...     ...
# 47518   Samoa  2019    2.18
# 47523   Samoa  2018    2.18
# 47528   Samoa  2017    2.06
# 47533   Samoa  2016    2.29
# 47538   Samoa  2015    2.10
#
# [940 rows x 3 columns]

# %%
df.to_excel("Resources\data_alcohol_clean.xlsx")
