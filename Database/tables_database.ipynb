# %%
# Import libraries
# Initial imports
import psycopg2
import sys
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.cluster import KMeans
import plotly.express as px
import hvplot.pandas
import re
from sqlalchemy import create_engine
import sqlalchemy

# %%
# Connection parameters
import ic_config
param_dic = {
    "host"      : ic_config.host,
    "database"  : ic_config.database,
    "user"      : ic_config.username,
    "password"  : ic_config.password
}

# Create connect function to connect to PostgresSQL server
def connect(param_dic):
    conn = None
    try:
        print("Connecting to the PostgreSQL database...")
        conn = psycopg2.connect(**param_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1)
    print ("Connection successful.")
    return conn

# %%
# Function to get the dataframe
def postgresql_to_dataframe(conn, select_query, column_names):
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
            print("Error: %s" % error)
            cursor.close()
    
    # Get list of tuples
    tuples = cursor.fetchall()
    cursor.close()
    
    # Create pandas dataframe
    df = pd.DataFrame(tuples, columns=column_names)
    return df

# %%
# Connect to the database
conn = connect(param_dic)

column_names = ["country", "happinessrank", "happinessscore", "gdp", "family", "lifeexpectancy", "freedom", "generosity", "trust", "lat", "lng", "alcohol_liperyear"]
df = postgresql_to_dataframe(conn, "select * from whr_2019", column_names)
df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful.
#                  country  happinessrank happinessscore      gdp   family  \
# 0                 Brazil             32          6.300  1.00400  1.43900
# 1                Uruguay             33          6.293  1.12400  1.46500
# 2              Singapore             34          6.262  1.57200  1.46300
# 3            El Salvador             35          6.253  0.79400  1.24200
# 4                  Italy             36          6.223  1.29400  1.48800
# ..                   ...            ...            ...      ...      ...
# 149          Congo [DRC]            127          4.418  0.09400  1.12500
# 150        Côte d'Ivoire             99          4.944  0.56900  0.80800
# 151      Myanmar [Burma]            131          4.360  0.71000  1.18100
# 152    Macedonia [FYROM]             84          5.274  0.98300  1.29400
# 153  Trinidad and Tobago             39          6.192  1.23100  1.47700
#
#     lifeexpectancy  freedom generosity    trust         lat         lng  \
# 0          0.80200  0.39000    0.09900  0.08600  -14.235004  -51.925280
# 1          0.89100  0.52300    0.12700  0.15000  -32.522779  -55.765835
# 2          1.14100  0.55600    0.27100  0.45300    1.352083  103.819836
# 3          0.78900  0.43000    0.09300  0.07400   13.794185  -88.896530
# 4          1.03900  0.23100    0.15800  0.03000   41.871940   12.567380
# ..             ...      ...        ...      ...         ...         ...
# 149        0.35700  0.26900    0.21200  0.05300   -4.038333   21.758664
# 150        0.23200  0.35200    0.15400  0.09000    7.539989   -5.547080
# 151        0.55500  0.52500    0.56600  0.17200   21.913965   95.956223
# 152        0.83800  0.34500    0.18500  0.03400   41.608635   21.745275
# 153        0.71300  0.48900    0.18500  0.01600   10.691803  -61.222503
#
#     alcohol_liperyear
# 0                19.3
# 1                15.7
# 2                 2.9
# 3                12.8
# 4                12.0
# ..                ...
# 149               7.1
# 150              21.7
# 151              17.6
# 152              None
# 153              14.2
#
# [154 rows x 12 columns]

# %%
# Connect to the database
conn = connect(param_dic)

column_names = ["country_code", "country"]
df2 = postgresql_to_dataframe(conn, "select * from countries", column_names)
df2
# Out:
# Connecting to the PostgreSQL database...
# Connection successful.
#     country_code               country
# 0             AD               Andorra
# 1             AE  United Arab Emirates
# 2             AF           Afghanistan
# 3             AG   Antigua and Barbuda
# 4             AI              Anguilla
# ..           ...                   ...
# 239           YE                 Yemen
# 240           YT               Mayotte
# 241           ZA          South Africa
# 242           ZM                Zambia
# 243           ZW              Zimbabwe
#
# [244 rows x 2 columns]

# %%
# Merge country codes and metrics
df_final = pd.merge(df,df2, on = "country")
df_final
# Out:
#                  country  happinessrank happinessscore      gdp   family  \
# 0                 Brazil             32          6.300  1.00400  1.43900
# 1                Uruguay             33          6.293  1.12400  1.46500
# 2              Singapore             34          6.262  1.57200  1.46300
# 3            El Salvador             35          6.253  0.79400  1.24200
# 4                  Italy             36          6.223  1.29400  1.48800
# ..                   ...            ...            ...      ...      ...
# 149          Congo [DRC]            127          4.418  0.09400  1.12500
# 150        Côte d'Ivoire             99          4.944  0.56900  0.80800
# 151      Myanmar [Burma]            131          4.360  0.71000  1.18100
# 152    Macedonia [FYROM]             84          5.274  0.98300  1.29400
# 153  Trinidad and Tobago             39          6.192  1.23100  1.47700
#
#     lifeexpectancy  freedom generosity    trust         lat         lng  \
# 0          0.80200  0.39000    0.09900  0.08600  -14.235004  -51.925280
# 1          0.89100  0.52300    0.12700  0.15000  -32.522779  -55.765835
# 2          1.14100  0.55600    0.27100  0.45300    1.352083  103.819836
# 3          0.78900  0.43000    0.09300  0.07400   13.794185  -88.896530
# 4          1.03900  0.23100    0.15800  0.03000   41.871940   12.567380
# ..             ...      ...        ...      ...         ...         ...
# 149        0.35700  0.26900    0.21200  0.05300   -4.038333   21.758664
# 150        0.23200  0.35200    0.15400  0.09000    7.539989   -5.547080
# 151        0.55500  0.52500    0.56600  0.17200   21.913965   95.956223
# 152        0.83800  0.34500    0.18500  0.03400   41.608635   21.745275
# 153        0.71300  0.48900    0.18500  0.01600   10.691803  -61.222503
#
#     alcohol_liperyear country_code
# 0                19.3           BR
# 1                15.7           UY
# 2                 2.9           SG
# 3                12.8           SV
# 4                12.0           IT
# ..                ...          ...
# 149               7.1           CD
# 150              21.7           CI
# 151              17.6           MM
# 152              None           MK
# 153              14.2           TT
#
# [154 rows x 13 columns]

# %%
##create happines rank table
happines_rank = df_final[["country_code","happinessrank","happinessscore"]]
happines_rank
# Out:
#     country_code  happinessrank happinessscore
# 0             BR             32          6.300
# 1             UY             33          6.293
# 2             SG             34          6.262
# 3             SV             35          6.253
# 4             IT             36          6.223
# ..           ...            ...            ...
# 149           CD            127          4.418
# 150           CI             99          4.944
# 151           MM            131          4.360
# 152           MK             84          5.274
# 153           TT             39          6.192
#
# [154 rows x 3 columns]

# %%
## export happines rank t
from config import db_password
"postgres://[user]:[password]@[location]:[port]/[database]"
db_string = f"postgresql://postgres:{db_password}@whr.csnc4l4qvlqd.us-east-2.rds.amazonaws.com/postgres"
engine = create_engine(db_string)
happines_rank.to_sql(name='happines_rank', con=engine, if_exists = "replace")
# Out:
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# DependentObjectsStillExist: cannot drop table happines_rank because other objects depend on it
# DETAIL:  view clusters depends on table happines_rank
# view whr_2019 depends on table happines_rank
# view act_vs_pred_happinessdata depends on view whr_2019
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-26-cddaa8e8c613> in <module>
#       3 db_string = f"postgresql://postgres:{db_password}@whr.csnc4l4qvlqd.us-east-2.rds.amazonaws.com/postgres"
#       4 engine = create_engine(db_string)
# ----> 5 happines_rank.to_sql(name='happines_rank', con=engine, if_exists = "replace")
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\Documents\Anaconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\Documents\Anaconda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\Documents\Anaconda\lib\site-packages\pandas\io\sql.py in create(self)
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#     724             elif self.if_exists == "replace":
# --> 725                 self.pd_sql.drop_table(self.name, self.schema)
#     726                 self._execute_create()
#     727             elif self.if_exists == "append":
#
# ~\Documents\Anaconda\lib\site-packages\pandas\io\sql.py in drop_table(self, table_name, schema)
#    1452         if self.has_table(table_name, schema):
#    1453             self.meta.reflect(only=[table_name], schema=schema)
# -> 1454             self.get_table(table_name, schema).drop()
#    1455             self.meta.clear()
#    1456
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\sql\schema.py in drop(self, bind, checkfirst)
#     937         if bind is None:
#     938             bind = _bind_or_error(self)
# --> 939         bind._run_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#     940
#     941     def tometadata(
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    2093     ):
#    2094         with self._optional_conn_ctx_manager(connection) as conn:
# -> 2095             conn._run_visitor(visitorcallable, element, **kwargs)
#    2096
#    2097     class _trans_ctx(object):
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, **kwargs)
#    1654
#    1655     def _run_visitor(self, visitorcallable, element, **kwargs):
# -> 1656         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    1657
#    1658
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     143             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     144             if meth:
# --> 145                 return meth(obj, **kw)
#     146
#     147     def iterate(self, obj):
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\sql\ddl.py in visit_table(self, table, drop_ok, _is_metadata_operation)
#    1007         )
#    1008
# -> 1009         self.connection.execute(DropTable(table))
#    1010
#    1011         # traverse client side defaults which may refer to server-side
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\sql\ddl.py in _execute_on_connection(self, connection, multiparams, params)
#      70
#      71     def _execute_on_connection(self, connection, multiparams, params):
# ---> 72         return connection._execute_ddl(self, multiparams, params)
#      73
#      74     def execute(self, bind=None, target=None):
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_ddl(self, ddl, multiparams, params)
#    1066             else None,
#    1067         )
# -> 1068         ret = self._execute_context(
#    1069             dialect,
#    1070             dialect.execution_ctx_cls._init_ddl,
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\Documents\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# InternalError: (psycopg2.errors.DependentObjectsStillExist) cannot drop table happines_rank because other objects depend on it
# DETAIL:  view clusters depends on table happines_rank
# view whr_2019 depends on table happines_rank
# view act_vs_pred_happinessdata depends on view whr_2019
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
# [SQL:
# DROP TABLE happines_rank]
# (Background on this error at: http://sqlalche.me/e/13/2j85)

# %%
##create gdp table
gdp = df_final[["country_code","gdp"]]
gdp
# Out:
#     country_code      gdp
# 0             BR  1.00400
# 1             UY  1.12400
# 2             SG  1.57200
# 3             SV  0.79400
# 4             IT  1.29400
# ..           ...      ...
# 149           CD  0.09400
# 150           CI  0.56900
# 151           MM  0.71000
# 152           MK  0.98300
# 153           TT  1.23100
#
# [154 rows x 2 columns]

# %%
##export gdp table to the database
gdp.to_sql(name='gdp', con=engine, if_exists = "replace")

# %%
#create family table
family = df_final[["country_code","family"]]
family
# Out:
#     country_code   family
# 0             BR  1.43900
# 1             UY  1.46500
# 2             SG  1.46300
# 3             SV  1.24200
# 4             IT  1.48800
# ..           ...      ...
# 149           CD  1.12500
# 150           CI  0.80800
# 151           MM  1.18100
# 152           MK  1.29400
# 153           TT  1.47700
#
# [154 rows x 2 columns]

# %%
##export family table to the database
family.to_sql(name='family', con=engine, if_exists = "replace")

# %%
##create life_expectancy table
life_expectancy = df_final[["country_code","lifeexpectancy"]]
life_expectancy
# Out:
#     country_code lifeexpectancy
# 0             BR        0.80200
# 1             UY        0.89100
# 2             SG        1.14100
# 3             SV        0.78900
# 4             IT        1.03900
# ..           ...            ...
# 149           CD        0.35700
# 150           CI        0.23200
# 151           MM        0.55500
# 152           MK        0.83800
# 153           TT        0.71300
#
# [154 rows x 2 columns]

# %%
## export life_expectancy table to the database
life_expectancy.to_sql(name='life_expectancy', con=engine, if_exists = "replace")

# %%
## create freedom table
freedom = df_final[["country_code","freedom"]]


freedom
# Out:
#     country_code  freedom
# 0             BR  0.39000
# 1             UY  0.52300
# 2             SG  0.55600
# 3             SV  0.43000
# 4             IT  0.23100
# ..           ...      ...
# 149           CD  0.26900
# 150           CI  0.35200
# 151           MM  0.52500
# 152           MK  0.34500
# 153           TT  0.48900
#
# [154 rows x 2 columns]

# %%
## export freedom table to the database

freedom.to_sql(name='freedom', con=engine, if_exists = "replace")

# %%
## create generosity table

generosity = df_final[["country_code","generosity"]]

generosity

# %%
## export generosity table to the database

generosity.to_sql(name='generosity', con=engine, if_exists = "replace")

# %%
## create alcohol table

alcohol = df_final[["country_code","alcohol_liperyear"]]
alcohol
# Out:
#     country_code alcohol_liperyear
# 0             BR              19.3
# 1             UY              15.7
# 2             SG               2.9
# 3             SV              12.8
# 4             IT              12.0
# ..           ...               ...
# 149           CD               7.1
# 150           CI              21.7
# 151           MM              17.6
# 152           MK              None
# 153           TT              14.2
#
# [154 rows x 2 columns]

# %%
## export alcohol table to the database

alcohol.to_sql(name='alcohol', con=engine, if_exists = "replace")

# %%
## create coordinates table

coordinates = df_final[["country_code","lat","lng"]]
coordinates
# Out:
#     country_code         lat         lng
# 0             BR  -14.235004  -51.925280
# 1             UY  -32.522779  -55.765835
# 2             SG    1.352083  103.819836
# 3             SV   13.794185  -88.896530
# 4             IT   41.871940   12.567380
# ..           ...         ...         ...
# 149           CD   -4.038333   21.758664
# 150           CI    7.539989   -5.547080
# 151           MM   21.913965   95.956223
# 152           MK   41.608635   21.745275
# 153           TT   10.691803  -61.222503
#
# [154 rows x 3 columns]

# %%
## export coordinates table to the database
coordinates.to_sql(name='coordinates', con=engine, if_exists = "replace")
